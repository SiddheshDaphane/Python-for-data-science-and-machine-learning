# %% [markdown]
# # Matplotlib
# Official Web page: https://matplotlib.org/stable/

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/siddheshdaphane/opt/anaconda3/envs/siddhesh
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       h6c40b1e_8          20 KB
#     brotli-bin-1.0.9           |       h6c40b1e_8          17 KB
#     ca-certificates-2024.9.24  |       hecd8cb5_0         131 KB
#     certifi-2024.8.30          |   py39hecd8cb5_0         164 KB
#     contourpy-1.2.0            |   py39ha357a0b_0         241 KB
#     fonttools-4.51.0           |   py39h6c40b1e_0         2.4 MB
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np 
import pandas as pd

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ### Basic Matplotlib Commands

# %%
plt.plot(x,y,'r') # 'r' is the color red
plt.xlabel('X Axis Title here')
plt.ylabel('Y Axis Title here')
plt.title('Staring Title Here')
plt.show()

# %% [markdown]
# ##### subploting
# plt.subplot(nrows,ncols,plot_number)
#
# plt.subplot(1,2,1)
# meaning grid of 1 row and 2 columns with last 1 as 1st graph

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'g')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')
plt.subplot(2,2,2)
plt.plot(y,x,'g')
plt.subplot(2,2,3)
plt.plot(x,y,'b*--')
plt.subplot(2,2,4)
plt.plot(y,x,'r--')

# %% [markdown]
# ##### Multiple Lines

# %%
plt.plot(x, np.sin(x), label='sin(x)')
plt.plot(x,np.cos(x), label='cos(x)')
plt.legend()
plt.show()

# %% [markdown]
# ##### Colors, Linestyles, and Markers

# %%
plt.plot(x, np.sin(x), color='red',linestyle='--', marker='o', label='sin(x)')
plt.plot(x, np.cos(x),color='blue', linestyle=':', marker='s', label='cos(x)')
plt.legend()

# %% [markdown]
# ##### Adjusting Axes
# Setting specific limits for the x and y axes

# %%
plt.plot(x, np.sin(x))
plt.xlim(0,5)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ## Matplotlib Object Oriented Method

# %%
# Create Figure (enpty canvas)
fig = plt.figure() 

axes = fig.add_axes([0.1,0.1,0.8,0.8]) # left, bottom, width, height (range 0 to 1)
axes.plot(x,y,'b')
axes.set_xlabel('Set x label')
axes.set_ylabel('Set y label')
axes.set_title('Set Title')
plt.show()

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # main axes
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) # inset axes

# Larger Figure axes 1
axes1.plot(x,y,'b')
axes1.set_xlabel('X_label_axes1')
axes1.set_ylabel('Y_label_axes1')
axes1.set_title('Axes 1 Title')

# Insert Figure axes 2
axes2.plot(y,x,'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %% [markdown]
# ### subplots()

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
s = pd.Series(axes)
s.count()
# Out:
# 2

# %%
for i in axes:
    i.plot(x,y,'b')
    i.set_xlabel('X')
    i.set_ylabel('Y')
    i.set_title('title')

fig

# %% [markdown]
# **A common issue with matplotlib is overlapping subplots or figures. We can use fig.tight_layout() or plt.tight_layout() method, which automatically adjusts the positions of the axes on the fighure canvas**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for i in axes:
    i.plot(x,y,'g')
    i.set_xlabel('x')
    i.set_ylabel('y')
    i.set_title('title')

fig
plt.tight_layout()

# %% [markdown]
# ### Figure size, aspect ratio and DPI
# **figsize** is a tuple of the width and height of the figure in inches
#
# **dpi** is the dots-per-inch (pixel per inch)

# %%
fig = plt.figure(figsize=(8,4), dpi=100)
fig

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');
